# %% [markdown]
# ## Plan
# * Identify NAN values
# * Replace rows with NAN values with the average state value of the feature

# %%
#Library Imports
import pandas as pd
import numpy as np
from IPython.display import display
pd.options.display.max_columns = None

# %%
#Import Datset
df = pd.read_csv("full_data.csv")
df.head()
# Out:
#            geo_id     county_name     state  total_pop  bachelors>  veterans  \
# 0  0500000US01001  Autauga County   Alabama      55380        26.6      12.6
# 1  0500000US01003  Baldwin County   Alabama     212830        31.9      11.8
# 2  0500000US01005  Barbour County   Alabama      25361        11.6       6.6
# 3  0500000US01007     Bibb County   Alabama      22493        10.4       8.0
# 4  0500000US01009   Blount County   Alabama      57681        13.1       7.7
#
#    white_collar  pink_collar  blue_collar  median_income  no_health_insurance  \
# 0          37.8         38.8         23.4        35769.0                  7.1
# 1          37.1         41.6         21.3        32257.0                  8.9
# 2          26.9         34.5         38.7        25323.0                 11.3
# 3          20.4         36.9         42.8        25860.0                 10.7
# 4          30.2         33.3         36.5        35500.0                 10.8
#
# ...

# %%
#Identify Rows with missing Data:
null_data = df[df.isna().any(axis=1)]
null_data
# Out:
#               geo_id        county_name           state  total_pop  \
# 0     0500000US01001     Autauga County         Alabama      55380
# 68    0500000US04003     Cochise County         Arizona     125867
# 69    0500000US04005    Coconino County         Arizona     141274
# 70    0500000US04007        Gila County         Arizona      53546
# 71    0500000US04009      Graham County         Arizona      37996
# 72    0500000US04011    Greenlee County         Arizona       9522
# 73    0500000US04012      La Paz County         Arizona      20793
# 74    0500000US04013    Maricopa County         Arizona    4328810
# 75    0500000US04015      Mohave County         Arizona     207695
# 76    0500000US04017      Navajo County         Arizona     109270
# 77    0500000US04019        Pima County         Arizona    1027207
# 78    0500000US04021       Pinal County         Arizona     432793
# 79    0500000US04023  Santa Cruz County         Arizona      46480
# ...

# %%
# Fill missing data for alabama:
al = df[df["state"]==" Alabama"]
al.fillna(0)
print(f'p_male:{np.mean(al["p_male"])};p_latino:{np.mean(al["p_latino"])}')
# Out:
# p_male:48.613636363636374;p_latino:3.4939393939393937

# %%
df["p_male"][0] = 48.6
df["p_latino"][0] = 3.5
null_data = df[df.isna().any(axis=1)]
null_data
# Out:
# C:\Users\teybo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\teybo\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               geo_id        county_name           state  total_pop  \
# 68    0500000US04003     Cochise County         Arizona     125867
# 69    0500000US04005    Coconino County         Arizona     141274
# 70    0500000US04007        Gila County         Arizona      53546
# ...

# %%
az = df[df["state"] == " Arizona"]
az.fillna(0)
print(f'p_male:{np.mean(az["p_male"])};p_latino:{np.mean(az["p_latino"])}')
# Out:
# p_male:49.5;p_latino:3.2

# %%
df["p_latino"][68:82] = 3.2
df["p_male"][68:82] = 49.5
null_data = df[df.isna().any(axis=1)]
null_data
# Out:
# C:\Users\teybo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\teybo\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               geo_id       county_name           state  total_pop  bachelors>  \
# 82    0500000US05001   Arkansas County        Arkansas      17914        15.8
# 83    0500000US05003     Ashley County        Arkansas      20270        12.3
# 84    0500000US05005     Baxter County        Arkansas      41427        17.9
# ...

# %%
ak = df[df["state"] == " Arkansas"]
az.fillna(0)
print(f'p_male:{np.mean(ak["p_male"])};p_latino:{np.mean(ak["p_latino"])}')
# Out:
# p_male:49.73666666666667;p_latino:11.466666666666669

# %%
df["p_latino"][82:97] = 11.5
df["p_male"][82:97] = 49.7
null_data = df[df.isna().any(axis=1)]
null_data
# Out:
# C:\Users\teybo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\teybo\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               geo_id       county_name           state  total_pop  bachelors>  \
# 549   0500000US16057      Latah County           Idaho      39505        45.4
# 1017  0500000US21109    Jackson County        Kentucky      13369        13.8
# 1398  0500000US28055  Issaquena County     Mississippi       1361         3.2
# ...

# %%
ida = df[df["state"] == " Idaho"]
az.fillna(0)
print(f'p_male:{np.mean(ida["p_male"])};p_latino:{np.mean(ida["p_latino"])}')
# Out:
# p_male:50.032558139534885;p_latino:6.706976744186047

# %%
df["p_male"][549] = 50.0
df["p_latino"][549] = 6.7
null_data = df[df.isna().any(axis=1)]
null_data
# Out:
# C:\Users\teybo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\teybo\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               geo_id       county_name           state  total_pop  bachelors>  \
# 1017  0500000US21109    Jackson County        Kentucky      13369        13.8
# 1398  0500000US28055  Issaquena County     Mississippi       1361         3.2
# 1449  0500000US28157  Wilkinson County     Mississippi       8875        13.7
# ...

# %%
kent = df[df["state"] == " Kentucky"]
az.fillna(0)
print(f'p_male:{np.mean(kent["p_male"])};p_latino:{np.mean(kent["p_latino"])}')
# Out:
# p_male:49.883333333333354;p_latino:4.860833333333333

# %%
df["p_male"][1017] = 49.9
df["p_latino"][1017] = 4.9
null_data = df[df.isna().any(axis=1)]
null_data.index
# Out:
# C:\Users\teybo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\teybo\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Int64Index([1017, 1398, 1449, 1573, 1584, 1628, 1681, 2339, 2355, 2390, 2643,
#             2665, 2751, 2969],
#            dtype='int64')

# %%
index = [1017, 1398, 1449, 1573, 1584, 1628, 1681, 2339, 2355, 2390,
            2665, 2751, 2969]
for i in index:
    info = df.iloc[i,:]
    state = info["state"]
    state = df[df["state"] == state]
    state.fillna(0)
    imm_m = np.mean(state["immigrants"])
    df["immigrants"][i] = imm_m
# Out:
# C:\Users\teybo\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
null_data = df[df.isna().any(axis=1)]
null_data
# Out:
#               geo_id    county_name   state  total_pop  bachelors>  veterans  \
# 2643  0500000US48301  Loving County   Texas         98         0.0       5.5
#
#       white_collar  pink_collar  blue_collar  median_income  \
# 2643          30.3          6.1         63.6            NaN
#
#       no_health_insurance  p_male  p_white  p_black  p_asian  p_latino  \
# 2643                 12.2    49.4     96.9      0.0      0.0      33.1
#
#       english_speaking  immigrants  gen_z  gen_y  gen_x  baby_boomer  \
# 2643              80.5       100.0    2.0    9.2   12.2         47.9
#
#       silent_gen  p_gop_20  p_dem_20  p_dem_16  p_gop_16
# 2643         3.1  0.909091  0.060606  0.890625    0.0625

# %%
tex = df[df["state"] == " Texas"]
tex.fillna(0)
print(f'p_male:{np.mean(tex["median_income"])};p_latino:{np.mean(tex["p_latino"])}')
# Out:
# p_male:30478.343873517788;p_latino:30.61692913385827

# %%
df["median_income"][2643] = 30478
# Out:
# C:\Users\teybo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.isna().sum()
# Out:
# geo_id                 0
# county_name            0
# state                  0
# total_pop              0
# bachelors>             0
# veterans               0
# white_collar           0
# pink_collar            0
# blue_collar            0
# median_income          0
# no_health_insurance    0
# p_male                 0
# p_white                0
# p_black                0
# p_asian                0
# p_latino               0
# english_speaking       0
# immigrants             0
# gen_z                  0
# gen_y                  0
# gen_x                  0
# baby_boomer            0
# silent_gen             0
# p_gop_20               0
# p_dem_20               0
# p_dem_16               0
# p_gop_16               0
# dtype: int64

# %%
df.to_csv("cleaned_full_data.csv",index=False)
